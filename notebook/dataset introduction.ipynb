# %%
import json
from pandas import json_normalize
import numpy as np

# %%
with open('../new_data.jsonl', encoding="utf-8", mode='r') as f:
    data = json.load(f)

# %%
code_df = json_normalize(data)

# %%
code_df
# Out:
#                                                     src complexity  \
# 0     import java.io.*;\nimport java.math.BigInteger...  quadratic
# 1     import java.util.Scanner;\n \npublic class pil...     linear
# 2     import java.io.BufferedReader;\nimport java.io...     linear
# 3     import java.util.*;\n\nimport java.io.*;\npubl...     linear
# 4     import java.io.OutputStream;\nimport java.io.I...     linear
# ...                                                 ...        ...
# 4512  import java.io.BufferedReader;\nimport java.io...         np
# 4513  import java.util.*;\nimport java.io.*;\n\npubl...         np
# 4514  \n/**\n * @author Juan Sebastian Beltran Rojas...         np
# 4515  import java.io.*;\nimport java.math.BigInteger...         np
# 4516  import java.io.*;\nimport java.util.*;\n\nimpo...         np
#
#                               problem        from
# 0         1179_B. Tolik and His Uncle  CODEFORCES
# 1                     1197_B. Pillars  CODEFORCES
# ...
